# %% [markdown]
# ### 1. Prepare a list of offices sorted by country, state, city.

# %%
import pymysql
import pandas as pd

host='127.0.0.1'
port="3306"
user='root'
password=''
database='classicmodels'

conn=pymysql.connect(
    host=host,
    port=int(port),
    user=user,
    passwd=password,
    db=database,
    charset='utf8mb4')

def run(sql):
    df=pd.read_sql_query(sql,conn)
    return df

# %%
run("select country, state, city from offices")
# Out:
#      country       state           city
# 0        USA          CA  San Francisco
# 1        USA          MA         Boston
# 2        USA          NY            NYC
# 3     France        None          Paris
# 4      Japan  Chiyoda-Ku          Tokyo
# 5  Australia        None         Sydney
# 6         UK        None         London

# %% [markdown]
# ### 2. How many employees are there in the company?

# %%
run("select count(*) as jumlah_employee from employees")
# Out:
#    jumlah_employee
# 0               23

# %% [markdown]
# ### 3. What is the total of payments received?

# %%
run("select sum(amount) as total_amount from payments")
# Out:
#    total_amount
# 0    8853839.23

# %% [markdown]
# ### 4. List the product lines that contain 'Cars'.

# %%
run("select productline from productlines where productline like '%cars%' ")
# Out:
#     productline
# 0  Classic Cars
# 1  Vintage Cars

# %% [markdown]
# ### 5. Report total payments for October 28, 2004.

# %%
run("select sum(amount) from payments where paymentdate='2004-10-28'")
# Out:
#    sum(amount)
# 0     47411.33

# %% [markdown]
# ### 6. Report those payments greater than \$100,000.

# %%
run("select amount from payments where amount>100000")
# Out:
#       amount
# 0  101244.59
# 1  111654.40
# 2  116208.40
# 3  120166.58
# 4  105743.00

# %% [markdown]
# ### 7. List the products in each product line.

# %%
run("select productline,productname from products")
# Out:
#           productline                                  productname
# 0         Motorcycles        1969 Harley Davidson Ultimate Chopper
# 1        Classic Cars                     1952 Alpine Renault 1300
# 2         Motorcycles                        1996 Moto Guzzi 1100i
# 3         Motorcycles         2003 Harley-Davidson Eagle Drag Bike
# 4        Classic Cars                          1972 Alfa Romeo GTA
# 5        Classic Cars                       1962 LanciaA Delta 16V
# 6        Classic Cars                            1968 Ford Mustang
# 7        Classic Cars                            2001 Ferrari Enzo
# 8    Trucks and Buses                               1958 Setra Bus
# 9         Motorcycles                             2002 Suzuki XREO
# 10       Classic Cars                           1969 Corvair Monza
# 11       Classic Cars                           1968 Dodge Charger
# 12       Classic Cars                             1969 Ford Falcon
# ...

# %% [markdown]
# ### 8. How many products in each product line?

# %%
run("select productline,count(productline) as jumlah_product from products group by productline")
# Out:
#         productline  jumlah_product
# 0      Classic Cars              38
# 1       Motorcycles              13
# 2            Planes              12
# 3             Ships               9
# 4            Trains               3
# 5  Trucks and Buses              11
# 6      Vintage Cars              24

# %% [markdown]
# ### 9. What is the minimum payment received?

# %%
run("select min(amount) as minimum_amount from payments")
# Out:
#    minimum_amount
# 0          615.45

# %% [markdown]
# ### 10. List all payments greater than twice the average payment.

# %%
run("select checkNumber,amount from payments where amount>(select 2*avg(amount) from payments)")
# Out:
#    checkNumber     amount
# 0     MA765515   82261.22
# 1     AE215433  101244.59
# 2     BG255406   85410.87
# 3      ET64396   83598.04
# 4     KI131716  111654.40
# 5      ID10962  116208.40
# 6     IN446258   65071.26
# 7     JE105477  120166.58
# 8     KM172879  105743.00
# 9     GN228846   85024.46
# 10    NQ865547   80375.24
# 11     DJ15149   85559.12
# 12    AL493079   75020.13

# %% [markdown]
# ### 11. What is the average percentage markup of the MSRP on buyPrice?

# %%
run("select avg((MSRP-buyprice)/buyprice*100) as presentase from products")
# Out:
#    presentase
# 0   88.702392

# %% [markdown]
# ### 12. How many distinct products does ClassicModels sell?

# %%
run("select count(DISTINCT productname) as produk_dijual from products")
# Out:
#    produk_dijual
# 0            110

# %% [markdown]
# ### 13. Report the name and city of customers who don't have sales representatives?

# %%
run("select customername, city from customers where salesrepemployeenumber is null")
# Out:
#                       customername              city
# 0               Havel & Zbyszek Co          Warszawa
# 1                Porto Imports Co.            Lisboa
# 2       Asian Shopping Network, Co         Singapore
# 3                  Natürlich Autos         Cunewalde
# 4                    ANG Resellers            Madrid
# 5         Messner Shopping Network         Frankfurt
# 6                Franken Gifts, Co           München
# 7                BG&E Collectables          Fribourg
# 8                 Schuyler Imports         Amsterdam
# 9                 Der Hund Imports            Berlin
# 10       Cramer Spezialitäten, Ltd       Brandenburg
# 11           Asian Treasures, Inc.              Cork
# 12            SAR Distributors, Co          Hatfield
# 13                 Kommission Auto           Münster
# 14          Lisboa Souveniers, Inc            Lisboa
# 15  Stuttgart Collectable Exchange         Stuttgart
# 16        Feuer Online Stores, Inc           Leipzig
# ...

# %% [markdown]
# ### 14. What are the names of executives with VP or Manager in their title? Use the CONCAT function to combine the employee's first name and last name into a single field for reporting.

# %%
run("SELECT CONCAT(firstName,' ',lastName) AS fullName FROM employees where jobtitle like '%vp%' or jobtitle like '%manager%'")
# Out:
#             fullName
# 0     Mary Patterson
# 1      Jeff Firrelli
# 2  William Patterson
# 3      Gerard Bondur
# 4        Anthony Bow

# %% [markdown]
# ### 15. Which orders have a value greater than $5,000?

# %%
run("select ordernumber, sum(quantityOrdered*priceeach) as total from orderdetails where ordernumber group by ordernumber having total>5000 ")
# Out:
#      ordernumber     total
# 0          10100  10223.83
# 1          10101  10549.01
# 2          10102   5494.78
# 3          10103  50218.95
# 4          10104  40206.20
# 5          10105  53959.21
# 6          10106  52151.81
# 7          10107  22292.62
# 8          10108  51001.22
# 9          10109  25833.14
# 10         10110  48425.69
# 11         10111  16537.85
# 12         10112   7674.94
# 13         10113  11044.30
# 14         10114  33383.14
# 15         10115  21665.98
# 16         10117  44380.15
# 17         10119  35826.33
# 18         10120  45864.03
# 19         10121  16700.47
# 20         10122  50824.66
# 21         10123  14571.44
# 22         10124  32641.98
# 23         10125   7565.08
# 24         10126  57131.92
# 25         10127  58841.35
# 26         10128  13884.99
# 27         10129  29429.14
# 28         10130   6036.96
# 29         10131  17032.29
# ..           ...       ...
# 273        10394  18102.74
# 274        10395  17928.09
# ...
